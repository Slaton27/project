# %%
import random

chars = "abcdefghijklmnopqrstuwxyzabcdefghijklmnopqrstuvwxyz0123456789!@#$%^&*()"

Length = input("how long should the password be? ")  #BUG: input is a string

password= []     # BUG : using a list instead of a string 

for i in length: #BUG: trying to iterate over a string number 
    random.choice  #bug: forgetting parentheses AND not using the return value 
    password += random.choice(chars)    #BUG: adding str to list 

Print("your random answer is: + Password)   # BUG :cannot concat string + list
# Out:
#   Cell In[7], line 13
#     Print("your random answer is: + Password)   # BUG :cannot concat string + list
#           ^
# SyntaxError: unterminated string literal (detected at line 13)

# %%
import random

chars =
"abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"

length + int(input("how long should the password be? "))

password = ""

for i in range(length):
    password += random.choice(chars)

print ("Your random password is:", password)
# Out:
#   Cell In[9], line 3
#     chars =
#            ^
# SyntaxError: invalid syntax

# %%
import random

chars ="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"

length + int(input("how long should the password be? "))

password = ""

for i in range(length):
    password += random.choice(chars)

print ("Your random password is:", password)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 import random
#       3 chars ="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"
# ----> 5 length + int(input("how long should the password be? "))
#       7 password = ""
#       9 for i in range(length):
#
# NameError: name 'length' is not defined

# %%
import random

chars ="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"

length + int(input("how long should the password be? "))

password = ""

for i in range(length):
    password = random.choice(chars)

print ("Your random password is:", password)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       1 import random
#       3 chars ="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"
# ----> 5 length + int(input("how long should the password be? "))
#       7 password = ""
#       9 for i in range(length):
#
# NameError: name 'length' is not defined

# %%
import random

chars ="abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789!@#$%^&*()"

length = int(input("how long should the password be? "))

password = ""

for i in range(length):
    password += random.choice(chars)

print ("Your random password is:", password)
# Out:
# how long should the password be?  10
# Your random password is: i5^d#Xt0%r
